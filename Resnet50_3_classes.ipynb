# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !unzip "drive/My Drive/Proyecto IA II/data_aug_3_classes/data_aug_3_classes.zip"
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#   inflating: base_dir/image_train/wasp/G00380.jpg
#   inflating: base_dir/image_train/wasp/I00033.jpg
#   inflating: base_dir/image_train/wasp/35718746_c8480981b7_n.jpg
#   inflating: base_dir/image_train/wasp/W00042.jpg
#   inflating: base_dir/image_train/wasp/H00280.jpg
#   inflating: base_dir/image_train/wasp/24477403119_6ea5021a9a_n.jpg
#   inflating: base_dir/image_train/wasp/28510555868_638db8d5a1_n.jpg
#   inflating: base_dir/image_train/wasp/I00121.jpg
#   inflating: base_dir/image_train/wasp/28598487656_b34e2c5483_n.jpg
#   inflating: base_dir/image_train/wasp/F00351.jpg
#   inflating: base_dir/image_train/wasp/F00263.jpg
#   inflating: base_dir/image_train/wasp/2656547303_286cab40ff_w.jpg
#   inflating: base_dir/image_train/wasp/F00327.jpg
#   inflating: base_dir/image_train/wasp/18715695736_35230141be_n.jpg
#   inflating: base_dir/image_train/wasp/5379033953_18a5db847c_w.jpg
#   inflating: base_dir/image_train/wasp/36388936203_94d8a989b2_n.jpg
#   inflating: base_dir/image_train/wasp/F00446.jpg
#   inflating: base_dir/image_train/wasp/J00328.jpg
#   inflating: base_dir/image_train/wasp/I00296.jpg
#   inflating: base_dir/image_train/wasp/I00096.jpg
#   inflating: base_dir/image_train/wasp/J00058.jpg
#   inflating: base_dir/image_train/wasp/I00097.jpg
#   inflating: base_dir/image_train/wasp/I00437.jpg
#   inflating: base_dir/image_train/wasp/H00256.jpg
#   inflating: base_dir/image_train/wasp/7547423236_84abeb6835_m.jpg
#   inflating: base_dir/image_train/wasp/J00230.jpg
#   inflating: base_dir/image_train/wasp/J00354.jpg
#   inflating: base_dir/image_train/wasp/I00319.jpg
#   inflating: base_dir/image_train/wasp/3850274809_255263f729_w.jpg
#   inflating: base_dir/image_train/wasp/B00057.jpg
#   inflating: base_dir/image_train/wasp/932887423_02ddc2e50e_n.jpg
#   inflating: base_dir/image_train/wasp/W00193.jpg
#   inflating: base_dir/image_train/wasp/I00456.jpg
#   inflating: base_dir/image_train/wasp/5897600184_aba4e25765_m.jpg
#   inflating: base_dir/image_train/wasp/H00238.jpg
#   inflating: base_dir/image_train/wasp/7482125582_edfd8e33e6_n.jpg
#   inflating: base_dir/image_train/wasp/3743653584_30a8efcf62_w.jpg
#   inflating: base_dir/image_train/wasp/3015575014_49ff3d50b7_m.jpg
#   inflating: base_dir/image_train/wasp/31556100566_0a2cf7d430_w.jpg
#   inflating: base_dir/image_train/wasp/I00126.jpg
#   inflating: base_dir/image_train/wasp/6965927403_15d5cb1f26_w.jpg
#   inflating: base_dir/image_train/wasp/H00248.jpg
#   inflating: base_dir/image_train/wasp/H00226.jpg
#   inflating: base_dir/image_train/wasp/I00041.jpg
#   inflating: base_dir/image_train/wasp/3905574409_f63b181e43_n.jpg
#   inflating: base_dir/image_train/wasp/W00103.jpg
#   inflating: base_dir/image_train/wasp/5289172356_ae9af2ebf3_n.jpg
#   inflating: base_dir/image_train/wasp/48439888756_72095a43f5_n.jpg
#   inflating: base_dir/image_train/wasp/H00134.jpg
#   inflating: base_dir/image_train/wasp/H00376.jpg
#   inflating: base_dir/image_train/wasp/3873037640_f2bbf8b55f_n.jpg
#   inflating: base_dir/image_train/wasp/36316163904_445466cfe3_m.jpg
#   inflating: base_dir/image_train/wasp/F00398.jpg
#   inflating: base_dir/image_train/wasp/5964593236_0ba00d2b80_m.jpg
#   inflating: base_dir/image_train/wasp/G00228.jpg
#   inflating: base_dir/image_train/wasp/I00058.jpg
#   inflating: base_dir/image_train/wasp/25168639927_f2190ebecd_n.jpg
#   inflating: base_dir/image_train/wasp/I00075.jpg
#   inflating: base_dir/image_train/wasp/W00480.jpg
#   inflating: base_dir/image_train/wasp/48263021156_5417d47e52_ca.jpg
#   inflating: base_dir/image_train/wasp/14752065345_b0a1895628_w.jpg
#   inflating: base_dir/image_train/wasp/9278354154_e97a92953e_n.jpg
#   inflating: base_dir/image_train/wasp/F00028.jpg
#   inflating: base_dir/image_train/wasp/15156957_925f735f03_m.jpg
#   inflating: base_dir/image_train/wasp/26576657996_c384bf9198_w.jpg
#   inflating: base_dir/image_train/wasp/27570082884_6d54bbe0ae_n.jpg
#   inflating: base_dir/image_train/wasp/3555474932_3ebe93211d_m.jpg
#   inflating: base_dir/image_train/wasp/G00334.jpg
#   inflating: base_dir/image_train/wasp/H00335.jpg
#   inflating: base_dir/image_train/wasp/W00019.jpg
#   inflating: base_dir/image_train/wasp/W00333.jpg
#   inflating: base_dir/image_train/wasp/J00110.jpg
#   inflating: base_dir/image_train/wasp/256220148_c5725ced57_m.jpg
#   inflating: base_dir/image_train/wasp/17250138055_aa87cdc2e6_n.jpg
#   inflating: base_dir/image_train/wasp/F00155.jpg
#   inflating: base_dir/image_train/wasp/35352344_c08510845c_m.jpg
#   inflating: base_dir/image_train/wasp/J00145.jpg
#   inflating: base_dir/image_train/wasp/W00263.jpg
#   inflating: base_dir/image_train/wasp/W00219.jpg
#   inflating: base_dir/image_train/wasp/J00239.jpg
#   inflating: base_dir/image_train/wasp/H00074.jpg
#   inflating: base_dir/image_train/wasp/J00189.jpg
#   inflating: base_dir/image_train/wasp/W00192.jpg
#   inflating: base_dir/image_train/wasp/F00369.jpg
#   inflating: base_dir/image_train/wasp/F00083.jpg
#   inflating: base_dir/image_train/wasp/G00142.jpg
#   inflating: base_dir/image_train/wasp/G00066.jpg
#   inflating: base_dir/image_train/wasp/E00079.jpg
#   inflating: base_dir/image_train/wasp/16179360671_979e66fa29_m.jpg
#   inflating: base_dir/image_train/wasp/W00235.jpg
#   inflating: base_dir/image_train/wasp/I00358.jpg
#   inflating: base_dir/image_train/wasp/F00253.jpg
#   inflating: base_dir/image_train/wasp/14873574775_0672675cb6_n.jpg
#   inflating: base_dir/image_train/wasp/H00361.jpg
#   inflating: base_dir/image_train/wasp/2508952844_5780e12ee6_n.jpg
#   inflating: base_dir/image_train/wasp/B00046.jpg
#   inflating: base_dir/image_train/wasp/F00014.jpg
#   inflating: base_dir/image_train/wasp/H00121.jpg
#   inflating: base_dir/image_train/wasp/5502719877_28fe903602_n.jpg
#   inflating: base_dir/image_train/wasp/49516529946_52b39258e8_m.jpg
#   inflating: base_dir/image_train/wasp/424647631_9a2b9b5a2d_n.jpg
#   inflating: base_dir/image_train/wasp/W00218.jpg
#   inflating: base_dir/image_train/wasp/43824888042_662c42bea0_m.jpg
#   inflating: base_dir/image_train/wasp/H00050.jpg
#   inflating: base_dir/image_train/wasp/E00088.jpg
#   inflating: base_dir/image_train/wasp/B00039.jpg
#   inflating: base_dir/image_train/wasp/4876825302_51e075d5f0_n.jpg
#   inflating: base_dir/image_train/wasp/W00329.jpg
#   inflating: base_dir/image_train/wasp/G00075.jpg
#   inflating: base_dir/image_train/wasp/H00167.jpg
#   inflating: base_dir/image_train/wasp/F00262.jpg
#   inflating: base_dir/image_train/wasp/5988496763_0937de764c_n.jpg
#   inflating: base_dir/image_train/wasp/H00345.jpg
#   inflating: base_dir/image_train/wasp/48219364626_29bcec219b_w.jpg
#   inflating: base_dir/image_train/wasp/G00007.jpg
#   inflating: base_dir/image_train/wasp/28797640645_fb583d8be2_n.jpg
#   inflating: base_dir/image_train/wasp/G00146.jpg
#   inflating: base_dir/image_train/wasp/G00255.jpg
#   inflating: base_dir/image_train/wasp/I00377.jpg
#   inflating: base_dir/image_train/wasp/22932848252_ae789e4c03_n.jpg
#   inflating: base_dir/image_train/wasp/3675884259_7a7ba76657_n.jpg
#   inflating: base_dir/image_train/wasp/F00333.jpg
#   inflating: base_dir/image_train/wasp/J00055.jpg
#   inflating: base_dir/image_train/wasp/14056058833_2db444d7f8_m.jpg
#   inflating: base_dir/image_train/wasp/9538492022_717d441dc3_m.jpg
#   inflating: base_dir/image_train/wasp/I00455.jpg
#   inflating: base_dir/image_train/wasp/I00083.jpg
#   inflating: base_dir/image_train/wasp/9640835585_8a98d8099e_n.jpg
#   inflating: base_dir/image_train/wasp/48122025167_3c79b60ec8_w.jpg
#   inflating: base_dir/image_train/wasp/W00437.jpg
#   inflating: base_dir/image_train/wasp/21545388930_ddee2f610d_m.jpg
#   inflating: base_dir/image_train/wasp/34673910070_cf16ca83b7_n.jpg
#   inflating: base_dir/image_train/wasp/F00086.jpg
#   inflating: base_dir/image_train/wasp/I00483.jpg
#   inflating: base_dir/image_train/wasp/G00173.jpg
#   inflating: base_dir/image_train/wasp/G00259.jpg
#   inflating: base_dir/image_train/wasp/3770854264_00150d662b_m.jpg
#   inflating: base_dir/image_train/wasp/W00047.jpg
#   inflating: base_dir/image_train/wasp/F00436.jpg
#   inflating: base_dir/image_train/wasp/21815698924_746cefe97b_n.jpg
#   inflating: base_dir/image_train/wasp/G00107.jpg
#   inflating: base_dir/image_train/wasp/W00115.jpg
#   inflating: base_dir/image_train/wasp/48761680787_b058eea506_m.jpg
#   inflating: base_dir/image_train/wasp/6741174713_bd594dfc67_n.jpg
#   inflating: base_dir/image_train/wasp/E00094.jpg
#   inflating: base_dir/image_train/wasp/W00202.jpg
#   inflating: base_dir/image_train/wasp/E00029.jpg
#   inflating: base_dir/image_train/wasp/I00414.jpg
#   inflating: base_dir/image_train/wasp/I00373.jpg
#   inflating: base_dir/image_train/wasp/W00012.jpg
#   inflating: base_dir/image_train/wasp/15038941388_f302839dd1_m.jpg
#   inflating: base_dir/image_train/wasp/F00034.jpg
#   inflating: base_dir/image_train/wasp/H00024.jpg
#   inflating: base_dir/image_train/wasp/15189006016_e484b5cb3f_n.jpg
#   inflating: base_dir/image_train/wasp/H00355.jpg
#   inflating: base_dir/image_train/wasp/F00124.jpg
#   inflating: base_dir/image_train/wasp/W00156.jpg
#   inflating: base_dir/image_train/wasp/E00078.jpg
#   inflating: base_dir/image_train/wasp/1476155595_1232c441bd_n.jpg
#   inflating: base_dir/image_train/wasp/11434531076_35f1ffa2e1_n.jpg
#   inflating: base_dir/image_train/wasp/42881063644_c54d51b8b2_w.jpg
#   inflating: base_dir/image_train/wasp/H00222.jpg
#   inflating: base_dir/image_train/wasp/459031284_87ebd0be56_n.jpg
#   inflating: base_dir/image_train/wasp/G00028.jpg
#   inflating: base_dir/image_train/wasp/F00100.jpg
#   inflating: base_dir/image_train/wasp/H00160.jpg
#   inflating: base_dir/image_train/wasp/28738804620_81950ae525_n.jpg
#   inflating: base_dir/image_train/wasp/20170847856_a8abf1b0ee_w.jpg
#   inflating: base_dir/image_train/wasp/5380392309_f40b020a55_n.jpg
#   inflating: base_dir/image_train/wasp/H00011.jpg
#   inflating: base_dir/image_train/wasp/H00382.jpg
#   inflating: base_dir/image_train/wasp/26479670083_320f30e1ac_n.jpg
#   inflating: base_dir/image_train/wasp/J00311.jpg
#   inflating: base_dir/image_train/wasp/G00323.jpg
#   inflating: base_dir/image_train/wasp/W00088.jpg
#   inflating: base_dir/image_train/wasp/2429940703_dd7b4b4f57_n.jpg
#   inflating: base_dir/image_train/wasp/4256517198_3658aabb1d_m.jpg
#   inflating: base_dir/image_train/wasp/I00192.jpg
#   inflating: base_dir/image_train/wasp/W00493.jpg
#   inflating: base_dir/image_train/wasp/19908113688_5ee31afaa7_m.jpg
#   inflating: base_dir/image_train/wasp/9487025594_a9f78fb64a_n.jpg
#   inflating: base_dir/image_train/wasp/12064366_e371d80c66_n.jpg
#   inflating: base_dir/image_train/wasp/I00263.jpg
#   inflating: base_dir/image_train/wasp/3737242301_944f9680cb_m.jpg
#   inflating: base_dir/image_train/wasp/I00351.jpg
#   inflating: base_dir/image_train/wasp/I00407.jpg
#   inflating: base_dir/image_train/wasp/15294916559_37c2c69318_n.jpg
#   inflating: base_dir/image_train/wasp/6066310112_918a2256e6_m.jpg
#   inflating: base_dir/image_train/wasp/W00046.jpg
#   inflating: base_dir/image_train/wasp/471320981_0dfb7623f6_m.jpg
#   inflating: base_dir/image_train/wasp/8952812709_be86e2de1a_m.jpg
#   inflating: base_dir/image_train/wasp/J00357.jpg
#   inflating: base_dir/image_train/wasp/F00160.jpg
#   inflating: base_dir/image_train/wasp/4836426924_f0682c2ea4_n.jpg
#   inflating: base_dir/image_train/wasp/W00371.jpg
#   inflating: base_dir/image_train/wasp/F00076.jpg
#   inflating: base_dir/image_train/wasp/H00316.jpg
#   inflating: base_dir/image_train/wasp/I00212.jpg
#   inflating: base_dir/image_train/wasp/21202304595_8ee1f0db6d_n.jpg
#   inflating: base_dir/image_train/wasp/I00364.jpg
#   inflating: base_dir/image_train/wasp/E00042.jpg
#   inflating: base_dir/image_train/wasp/W00455.jpg
#   inflating: base_dir/image_train/wasp/F00088.jpg
#   inflating: base_dir/image_train/wasp/14626023559_ed9b120f4c_n.jpg
#   inflating: base_dir/image_train/wasp/3605953663_f6e9364af9_m.jpg
#   inflating: base_dir/image_train/wasp/F00432.jpg
#   inflating: base_dir/image_train/wasp/J00340.jpg
#   inflating: base_dir/image_train/wasp/_2921_4686778.jpg
#   inflating: base_dir/image_train/wasp/6102983549_96498390bf_n.jpg
#   inflating: base_dir/image_train/wasp/G00070.jpg
#   inflating: base_dir/image_train/wasp/I00013.jpg
#   inflating: base_dir/image_train/wasp/6996837383_2a1da5dcb3_n.jpg
#   inflating: base_dir/image_train/wasp/G00181.jpg
#   inflating: base_dir/image_train/wasp/W00122.jpg
#   inflating: base_dir/image_train/wasp/H00362.jpg
#   inflating: base_dir/image_train/wasp/27636227_f32841ba8f_n.jpg
#   inflating: base_dir/image_train/wasp/W00221.jpg
#   inflating: base_dir/image_train/wasp/14660886449_ab840d1b7e_m.jpg
#   inflating: base_dir/image_train/wasp/I00274.jpg
#   inflating: base_dir/image_train/wasp/I00470.jpg
#   inflating: base_dir/image_train/wasp/J00292.jpg
#   inflating: base_dir/image_train/wasp/26438301116_2e3eb5f5aa_n.jpg
#   inflating: base_dir/image_train/wasp/37668275755_fd8854ee03_n.jpg
#   inflating: base_dir/image_train/wasp/J00233.jpg
#   inflating: base_dir/image_train/wasp/B00015.jpg
#   inflating: base_dir/image_train/wasp/14644771777_1fdc073f56_n.jpg
#   inflating: base_dir/image_train/wasp/I00306.jpg
#   inflating: base_dir/image_train/wasp/160164715_447c983834_m.jpg
#   inflating: base_dir/image_train/wasp/H00318.jpg
#   inflating: base_dir/image_train/wasp/G00189.jpg
#   inflating: base_dir/image_train/wasp/49782791091_f462e14011_n.jpg
#   inflating: base_dir/image_train/wasp/I00068.jpg
#   inflating: base_dir/image_train/wasp/F00015.jpg
#   inflating: base_dir/image_train/wasp/H00234.jpg
#   inflating: base_dir/image_train/wasp/W00377.jpg
#   inflating: base_dir/image_train/wasp/5769973939_052c816913_n.jpg
#   inflating: base_dir/image_train/wasp/3898978048_de3d1c5c34_m.jpg
#   inflating: base_dir/image_train/wasp/I00260.jpg
#   inflating: base_dir/image_train/wasp/G00161.jpg
#   inflating: base_dir/image_train/wasp/36184201216_02d760cf79_n.jpg
#   inflating: base_dir/image_train/wasp/J00244.jpg
#   inflating: base_dir/image_train/wasp/I00365.jpg
#   inflating: base_dir/image_train/wasp/448839099_caefd1b459_n.jpg
#   inflating: base_dir/image_train/wasp/J00332.jpg
#   inflating: base_dir/image_train/wasp/J00136.jpg
#   inflating: base_dir/image_train/wasp/G00096.jpg
#   inflating: base_dir/image_train/wasp/I00281.jpg
#   inflating: base_dir/image_train/wasp/F00401.jpg
#   inflating: base_dir/image_train/wasp/H00003.jpg
#   inflating: base_dir/image_train/wasp/7625915788_7c30cb628f_m.jpg
#   inflating: base_dir/image_train/wasp/867041088_da82ba75b8_n.jpg
#   inflating: base_dir/image_train/wasp/F00440.jpg
#   inflating: base_dir/image_train/wasp/W00034.jpg
#   inflating: base_dir/image_train/wasp/3699560674_4566e69d4d_m.jpg
#   inflating: base_dir/image_train/wasp/_3275_4299255.jpg
#   inflating: base_dir/image_train/wasp/F00387.jpg
#   inflating: base_dir/image_train/wasp/49967618332_3205683802_n.jpg
#   inflating: base_dir/image_train/wasp/2174705885_77bfc742fe_n.jpg
#   inflating: base_dir/image_train/wasp/35598914525_758eed0fd7_m.jpg
#   inflating: base_dir/image_train/wasp/H00089.jpg
#   inflating: base_dir/image_train/wasp/I00049.jpg
#   inflating: base_dir/image_train/wasp/2725151607_9dd1a92959_n.jpg
#   inflating: base_dir/image_train/wasp/18594343629_acb1e13b81_n.jpg
#   inflating: base_dir/image_train/wasp/G00324.jpg
#   inflating: base_dir/image_train/wasp/I00109.jpg
#   inflating: base_dir/image_train/wasp/2281791495_dc14da957d_n.jpg
#   inflating: base_dir/image_train/wasp/W00074.jpg
#   inflating: base_dir/image_train/wasp/H00133.jpg
#   inflating: base_dir/image_train/wasp/H00021.jpg
#   inflating: base_dir/image_train/wasp/44662375654_2ef1c2e6a7_n.jpg
#   inflating: base_dir/image_train/wasp/J00156.jpg
#   inflating: base_dir/image_train/wasp/5474679272_19759eea91_n.jpg
#   inflating: base_dir/image_train/wasp/16259879269_e3df5e282a_n.jpg
#   inflating: base_dir/image_train/wasp/16669513945_8a00349315_n.jpg
#   inflating: base_dir/image_train/wasp/I00305.jpg
#   inflating: base_dir/image_train/wasp/F00283.jpg
#   inflating: base_dir/image_train/wasp/46201485_15ee3e6a80_m.jpg
#   inflating: base_dir/image_train/wasp/H00204.jpg
#   inflating: base_dir/image_train/wasp/25299351174_5f9440b6e4_n.jpg
#   inflating: base_dir/image_train/wasp/W00401.jpg
#   inflating: base_dir/image_train/wasp/W00204.jpg
#   inflating: base_dir/image_train/wasp/4673775557_97d17d9753_m.jpg
#   inflating: base_dir/image_train/wasp/H00042.jpg
#   inflating: base_dir/image_train/wasp/H00244.jpg
#   inflating: base_dir/image_train/wasp/I00479.jpg
#   inflating: base_dir/image_train/wasp/W00310.jpg
#   inflating: base_dir/image_train/wasp/5803076134_2c8c3989f3_n.jpg
#   inflating: base_dir/image_train/wasp/I00206.jpg
#   inflating: base_dir/image_train/wasp/14902486519_2c012671f0_n.jpg
#   inflating: base_dir/image_train/wasp/6090819150_4a0d03bd63_n.jpg
#   inflating: base_dir/image_val/wasp/H00351.jpg
#   inflating: base_dir/image_val/wasp/130032324_b64f732484_n.jpg
#   inflating: base_dir/image_val/wasp/3524320798_4bc65839f8_n.jpg
#   inflating: base_dir/image_val/wasp/J00198.jpg
#   inflating: base_dir/image_val/wasp/4894996245_1b080721aa_n.jpg
#   inflating: base_dir/image_val/wasp/15295156508_e0034eb0cd_n.jpg
#   inflating: base_dir/image_val/wasp/I00488.jpg
#   inflating: base_dir/image_val/wasp/G00137.jpg
#   inflating: base_dir/image_val/wasp/J00144.jpg
#   inflating: base_dir/image_val/wasp/3905027529_f348126b66_n.jpg
#   inflating: base_dir/image_val/wasp/W00281.jpg
#   inflating: base_dir/image_val/wasp/G00102.jpg
#   inflating: base_dir/image_val/wasp/J00352.jpg
#   inflating: base_dir/image_val/wasp/I00438.jpg
#   inflating: base_dir/image_val/wasp/F00226.jpg
#   inflating: base_dir/image_val/wasp/4673775707_c06c3e0ab8_n.jpg
#   inflating: base_dir/image_val/wasp/49248781133_79981b1bb3_m.jpg
#   inflating: base_dir/image_val/wasp/906408394_d1a0a75e6d_n.jpg
#   inflating: base_dir/image_val/wasp/515040601_408b117716_m.jpg
#   inflating: base_dir/image_val/wasp/W00065.jpg
#   inflating: base_dir/image_val/wasp/8283988951_3ea4276cf1_n.jpg
#   inflating: base_dir/image_val/wasp/I00371.jpg
#   inflating: base_dir/image_val/wasp/6264875219_28b873e13c_n.jpg
#   inflating: base_dir/image_val/wasp/6986319895_76ecac243d_n.jpg
#   inflating: base_dir/image_val/wasp/I00044.jpg
#   inflating: base_dir/image_val/wasp/W00256.jpg

# %%
#@title **Librerias**
import os
import shutil
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from tensorflow.keras.metrics import categorical_accuracy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import BatchNormalization, Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score, classification_report, roc_auc_score

# %%
#MODELO RESNET50 CON TRANSFER LEARNING Y FINE-TUNNING 

#CARGANDO EL MODELO CON LOS PESOS PRE-ENTRENADOS DE IMAGENET
base_model = tf.keras.applications.ResNet50(
    include_top=False, weights='imagenet', input_tensor=None, input_shape=(224,224,3),
     classes=4, pooling='max', classifier_activation='softmax') 

base_model.trainable = True
set_trainable = False

#FINE TUNNING DEL ÚLTIMO BLOQUE CONVOLUCIONAL
for layer in base_model.layers:
  if layer.name == 'conv4_block4_3_conv':
    set_trainable = True
  if set_trainable: 
    layer.trainable = True
  else:
    layer.trainable = False

base_model.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_3[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 56, 56, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 56, 56, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 56, 56, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 56, 56, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 56, 56, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 56, 56, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 56, 56, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 56, 56, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 56, 56, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 56, 56, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 28, 28, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 28, 28, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 28, 28, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 28, 28, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 28, 28, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 28, 28, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 28, 28, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 28, 28, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 28, 28, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 28, 28, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 28, 28, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 28, 28, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 28, 28, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 14, 14, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 14, 14, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 14, 14, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 14, 14, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 14, 14, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 14, 14, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 14, 14, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 14, 14, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 14, 14, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 14, 14, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 14, 14, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 14, 14, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 14, 14, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 14, 14, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 14, 14, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 14, 14, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 14, 14, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 7, 7, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 7, 7, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 7, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 7, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 7, 7, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 7, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 7, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 7, 7, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 7, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 7, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 7, 7, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 7, 7, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# max_pool (GlobalMaxPooling2D)   (None, 2048)         0           conv5_block3_out[0][0]
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 17,478,656
# Non-trainable params: 6,109,056
# __________________________________________________________________________________________________

# %%
#PLANTEAMIENTO DEL MODELO SECUENCIAL Y ADICIÓN DE LAS ÚLTIMAS CAPAS DE SALIDA
model = Sequential()
model.add(base_model)
model.add(Dropout(0.1))
model.add(BatchNormalization())
model.add(Dense(256, activation="relu"))
model.add(Dropout(0.1))
model.add(BatchNormalization())
model.add(Dense(3, activation="softmax")) #FUNCIÓN DE ACTIVACIÓN SOFTMAX, OUTPUT 7 CLASES 

model.compile(Adam(0.001, decay=0.001/20), loss="categorical_crossentropy", metrics=[categorical_accuracy])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 2048)              23587712
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 2048)              8192
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               524544
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 771
# =================================================================
# Total params: 24,122,243
# Trainable params: 18,008,579
# Non-trainable params: 6,113,664
# _________________________________________________________________

# %%
#CARGAR LOS DATOS
train_dir='/content/base_dir/image_train'
val_dir='/content/base_dir/image_val'
test_dir='/content/base_dir/image_test'

IMAGE_SHAPE = (224, 224, 3)
batch_size = 32

data_generator = ImageDataGenerator()

train_flow_param = {
    "directory": train_dir,
    "batch_size": batch_size,
    "target_size": IMAGE_SHAPE[:2],
}
train_flow = data_generator.flow_from_directory(**train_flow_param)

val_flow_param = {
    "directory": val_dir,
    "batch_size": batch_size,
    "target_size": IMAGE_SHAPE[:2],
    "shuffle": False 
}
val_flow = data_generator.flow_from_directory(**val_flow_param)

test_flow_param = {
    "directory": test_dir,
    "target_size": IMAGE_SHAPE[:2],
    "batch_size" : 1,
    "shuffle": False 
}
test_flow = data_generator.flow_from_directory(**test_flow_param)
# Out:
# Found 11971 images belonging to 3 classes.
# Found 1056 images belonging to 3 classes.
# Found 1057 images belonging to 3 classes.

# %%
#PARAMETROS PARA EL ENTRENAMIENTO

filepath = "model.h5"

checkpoint_param = {
    "filepath": filepath,
    "monitor": "val_categorical_accuracy",
    "verbose": 1,
    "save_best_only": True,
    "mode": "max"
}
checkpoint = ModelCheckpoint(**checkpoint_param)

lr_decay_params = {
    "monitor": "val_loss",
    "factor": 0.5,
    "patience": 2,
    "min_lr": 1e-5
}
lr_decay = ReduceLROnPlateau(**lr_decay_params)

# %%
#ENTRENAMIENTO

fit_params = {
    "generator": train_flow,
    "steps_per_epoch": train_flow.n // batch_size,
    "epochs": 20,
    "verbose": 1,
    "validation_data": val_flow,
    "validation_steps": val_flow.n // batch_size,
    "callbacks": [checkpoint, lr_decay]
}
print("Training the model...")

history = model.fit_generator(**fit_params)

print("Done!")
# Out:
# Training the model...
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 374/374 [==============================] - 73s 186ms/step - loss: 0.4394 - categorical_accuracy: 0.8516 - val_loss: 0.2073 - val_categorical_accuracy: 0.9186
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.91856, saving model to model.h5
# Epoch 2/20
# 374/374 [==============================] - 68s 182ms/step - loss: 0.1653 - categorical_accuracy: 0.9422 - val_loss: 0.2254 - val_categorical_accuracy: 0.9242
#
# Epoch 00002: val_categorical_accuracy improved from 0.91856 to 0.92424, saving model to model.h5
# Epoch 3/20
# 374/374 [==============================] - 68s 182ms/step - loss: 0.0759 - categorical_accuracy: 0.9762 - val_loss: 0.1911 - val_categorical_accuracy: 0.9366
#
# Epoch 00003: val_categorical_accuracy improved from 0.92424 to 0.93655, saving model to model.h5
# Epoch 4/20
# 374/374 [==============================] - 68s 182ms/step - loss: 0.0343 - categorical_accuracy: 0.9898 - val_loss: 0.1882 - val_categorical_accuracy: 0.9451
#
# Epoch 00004: val_categorical_accuracy improved from 0.93655 to 0.94508, saving model to model.h5
# Epoch 5/20
# 374/374 [==============================] - 68s 182ms/step - loss: 0.0385 - categorical_accuracy: 0.9889 - val_loss: 0.1903 - val_categorical_accuracy: 0.9460
#
# Epoch 00005: val_categorical_accuracy improved from 0.94508 to 0.94602, saving model to model.h5
# Epoch 6/20
# 374/374 [==============================] - 68s 182ms/step - loss: 0.0133 - categorical_accuracy: 0.9966 - val_loss: 0.1931 - val_categorical_accuracy: 0.9489
#
# Epoch 00006: val_categorical_accuracy improved from 0.94602 to 0.94886, saving model to model.h5
# Epoch 7/20
# 374/374 [==============================] - 68s 182ms/step - loss: 0.0117 - categorical_accuracy: 0.9967 - val_loss: 0.1939 - val_categorical_accuracy: 0.9508
#
# Epoch 00007: val_categorical_accuracy improved from 0.94886 to 0.95076, saving model to model.h5
# Epoch 8/20
# 374/374 [==============================] - 68s 182ms/step - loss: 0.0105 - categorical_accuracy: 0.9975 - val_loss: 0.1927 - val_categorical_accuracy: 0.9527
#
# Epoch 00008: val_categorical_accuracy improved from 0.95076 to 0.95265, saving model to model.h5
# Epoch 9/20
# 374/374 [==============================] - 68s 182ms/step - loss: 0.0076 - categorical_accuracy: 0.9980 - val_loss: 0.1928 - val_categorical_accuracy: 0.9527
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.95265
# Epoch 10/20
# 374/374 [==============================] - 68s 182ms/step - loss: 0.0094 - categorical_accuracy: 0.9972 - val_loss: 0.1912 - val_categorical_accuracy: 0.9527
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.95265
# Epoch 11/20
# 374/374 [==============================] - 68s 182ms/step - loss: 0.0079 - categorical_accuracy: 0.9981 - val_loss: 0.1936 - val_categorical_accuracy: 0.9517
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.95265
# Epoch 12/20
# 374/374 [==============================] - 68s 181ms/step - loss: 0.0058 - categorical_accuracy: 0.9990 - val_loss: 0.1927 - val_categorical_accuracy: 0.9517
#
# Epoch 00012: val_categorical_accuracy did not improve from 0.95265
# Epoch 13/20
# 374/374 [==============================] - 68s 182ms/step - loss: 0.0065 - categorical_accuracy: 0.9984 - val_loss: 0.1931 - val_categorical_accuracy: 0.9536
#
# Epoch 00013: val_categorical_accuracy improved from 0.95265 to 0.95360, saving model to model.h5
# Epoch 14/20
# 374/374 [==============================] - 68s 182ms/step - loss: 0.0063 - categorical_accuracy: 0.9988 - val_loss: 0.1943 - val_categorical_accuracy: 0.9527
#
# Epoch 00014: val_categorical_accuracy did not improve from 0.95360
# Epoch 15/20
# 374/374 [==============================] - 68s 182ms/step - loss: 0.0061 - categorical_accuracy: 0.9987 - val_loss: 0.1917 - val_categorical_accuracy: 0.9527
#
# Epoch 00015: val_categorical_accuracy did not improve from 0.95360
# Epoch 16/20
# 374/374 [==============================] - 68s 182ms/step - loss: 0.0085 - categorical_accuracy: 0.9971 - val_loss: 0.1944 - val_categorical_accuracy: 0.9527
#
# Epoch 00016: val_categorical_accuracy did not improve from 0.95360
# Epoch 17/20
# 374/374 [==============================] - 68s 182ms/step - loss: 0.0062 - categorical_accuracy: 0.9986 - val_loss: 0.1931 - val_categorical_accuracy: 0.9536
#
# Epoch 00017: val_categorical_accuracy did not improve from 0.95360
# Epoch 18/20
# 374/374 [==============================] - 68s 182ms/step - loss: 0.0053 - categorical_accuracy: 0.9986 - val_loss: 0.1954 - val_categorical_accuracy: 0.9536
#
# Epoch 00018: val_categorical_accuracy did not improve from 0.95360
# Epoch 19/20
# 374/374 [==============================] - 68s 182ms/step - loss: 0.0050 - categorical_accuracy: 0.9988 - val_loss: 0.1958 - val_categorical_accuracy: 0.9527
#
# Epoch 00019: val_categorical_accuracy did not improve from 0.95360
# Epoch 20/20
# 374/374 [==============================] - 68s 182ms/step - loss: 0.0054 - categorical_accuracy: 0.9990 - val_loss: 0.1948 - val_categorical_accuracy: 0.9536
#
# Epoch 00020: val_categorical_accuracy did not improve from 0.95360
# Done!

# %%
#Evaluar el modelo con categorical accuracy y f1_score en la validacion
y_val_true = val_flow.classes
y_val_pred = np.argmax(model.predict_generator(val_flow, steps=len(val_flow)), axis=1)

_, val_acc = model.evaluate_generator(val_flow, steps=len(val_flow))
val_precision_score = precision_score(y_val_true, y_val_pred, average="weighted")
val_f1_score = f1_score(y_val_true, y_val_pred, average="weighted")
val_recall_score = recall_score(y_val_true, y_val_pred, average='weighted')

print("Validation accuracy: {:.4f}".format(val_acc))
print("Validation Precision: {:.4f}".format(val_precision_score))
print("Validation F1 score: {:.4f}".format(val_f1_score))
print("Validation Recall score: {:.4f}".format(val_recall_score))
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1905: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1877: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# Validation accuracy: 0.9536
# Validation Precision: 0.9537
# Validation F1 score: 0.9535
# Validation Recall score: 0.9536

# %%
#Evaluar el modelo con categorical accuracy y f1_score en el test

y_test_true = test_flow.classes
y_test_pred = np.argmax(model.predict_generator(test_flow, steps=len(test_flow)), axis=1)

_, test_acc = model.evaluate_generator(test_flow, steps=len(test_flow))
test_precision_score = precision_score(y_test_true, y_test_pred, average="weighted")
test_f1_score = f1_score(y_test_true, y_test_pred, average="weighted")
test_recall_score = recall_score(y_test_true, y_test_pred, average='weighted')

print("Test accuracy: {:.4f}".format(test_acc))
print("Test Precision: {:.4f}".format(test_precision_score))
print("Test F1 score: {:.4f}".format(test_f1_score))
print("Test Recall score: {:.4f}".format(test_recall_score))
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1905: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1877: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# Test accuracy: 0.9508
# Test Precision: 0.9507
# Test F1 score: 0.9508
# Test Recall score: 0.9508

# %%
#OBTENER EL HISTORIAL DE LOS DATOS DEL ENTRENAMIENTO

loss_train = history.history["loss"]
acc_train = history.history["categorical_accuracy"]
loss_val = history.history["val_loss"]
acc_val = history.history["val_categorical_accuracy"]
epochs = np.arange(1, len(loss_train) + 1)

print("Loss Train = " + str(loss_train))
print("Acc Train = " + str(acc_train))
print("Loss Val = " + str(loss_val))
print("Acc Val = " + str(acc_val))
# Out:
# Loss Train = [0.3213683068752289, 0.1699809581041336, 0.05974210798740387, 0.02758278325200081, 0.03266086429357529, 0.014438373036682606, 0.01183250267058611, 0.00980277732014656, 0.007353359367698431, 0.007446292322129011, 0.007539078127592802, 0.00606759637594223, 0.007600841112434864, 0.005424723029136658, 0.006128319539129734, 0.0071472832933068275, 0.007326736114919186, 0.004507476929575205, 0.005103103816509247, 0.004803474526852369]
# Acc Train = [0.8876790404319763, 0.9384370446205139, 0.9804003834724426, 0.9917078614234924, 0.9908702373504639, 0.9965658783912659, 0.9967333674430847, 0.9974872469902039, 0.9984085559844971, 0.9981573224067688, 0.9982410669326782, 0.9986598491668701, 0.9981573224067688, 0.9991624355316162, 0.9984923601150513, 0.9981573224067688, 0.9983248114585876, 0.999078631401062, 0.9987435936927795, 0.999078631401062]
# Loss Val = [0.20733703672885895, 0.22542476654052734, 0.19114205241203308, 0.18820463120937347, 0.19031371176242828, 0.19309557974338531, 0.19390136003494263, 0.192714124917984, 0.19281411170959473, 0.19121496379375458, 0.19357949495315552, 0.19272376596927643, 0.19309628009796143, 0.19425620138645172, 0.19170750677585602, 0.19443859159946442, 0.1930609494447708, 0.19543224573135376, 0.19584514200687408, 0.1948467344045639]
# Acc Val = [0.9185606241226196, 0.9242424368858337, 0.9365530014038086, 0.9450757503509521, 0.9460227489471436, 0.9488636255264282, 0.9507575631141663, 0.9526515007019043, 0.9526515007019043, 0.9526515007019043, 0.9517045617103577, 0.9517045617103577, 0.9535984992980957, 0.9526515007019043, 0.9526515007019043, 0.9526515007019043, 0.9535984992980957, 0.9535984992980957, 0.9526515007019043, 0.9535984992980957]

# %%
os.mkdir('Resultados')

# %%
#PLOTEO DE LOS DATOS DE ACCURACY DEL ENTRENAMIENTO Y DE LA VALIDACION CONTRA NUMERO DE EPOCAS 

import matplotlib.pyplot as plt
import numpy as np

from pylab import *

#GRAFICA ACCURACY
x = np.linspace(1, 20, 20)
#train y val
acctrain = acc_train
accval = acc_val

plt.plot(x, acctrain, label='Train',color="green", linestyle="--",linewidth=2.5)
plt.plot(x, accval, label='Validaiton',color="orange",linestyle="-.", linewidth=2.5)
xticks(fontsize=12)
yticks(fontsize=12)
plt.xlabel('Epochs',fontsize=14)
plt.ylabel('Accuracy',fontsize=14)

plt.title("Accuracy vs Epochs",fontsize=15)

plt.legend(fontsize=12)
plt.savefig("Resultados/accuracy.pdf", bbox_inches="tight")
plt.savefig("Resultados/accuracy.png", bbox_inches="tight")
plt.show()

# %%
#GRAFICA LOSS
x = np.linspace(1, 20, 20)

plt.plot(x, loss_train, label='Training',color="green", linestyle="--",linewidth=2.5)
plt.plot(x, loss_val, label='Validation',color="orange",linestyle="-.", linewidth=2.5)

xticks(fontsize=12)
yticks(fontsize=12)
plt.xlabel('Epochs',fontsize=14)
plt.ylabel('Loss',fontsize=14)

plt.title("Loss vs Epochs",fontsize=15)

plt.legend(fontsize=12)
plt.savefig("Resultados/loss.pdf", bbox_inches="tight")
plt.savefig("Resultados/loss.png", bbox_inches="tight")
plt.show()

# %%
#MATRIZ DE CONFUSION

import itertools
import matplotlib.pyplot as plt

labels = ['bee', 'insect', 'wasp']
conf_mat = confusion_matrix(y_test_true, y_test_pred)
conf_mat = conf_mat / conf_mat.astype(np.float).sum(axis=1, keepdims=True)
prediction = model.predict(test_flow, batch_size=16)
hide_ticks =True
plt.figure(figsize= (12,12))

def plot_confusion_matrix(cm,
                          normalize=False,
                          cmap=plt.cm.Greens,
                          axis=1): 

    plt.imshow(cm, interpolation='nearest', cmap=cmap)

    cbar = plt.colorbar(fraction=0.046, pad=0.04)
    cbar.ax.tick_params(labelsize=24) 
    plt.xticks(range(3), labels, fontsize=24)
    plt.yticks(range(3), labels, fontsize=24)

    fmt = '.2f' if normalize else '.2f'
    thresh = 50
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black",fontsize=30)

    plt.ylabel('True Label',fontsize=24)
    plt.xlabel('Prediction',fontsize=24)
    plt.title('Confussion Matrix',fontsize=24)
    plt.tight_layout()
plot_confusion_matrix(conf_mat)
plt.savefig("Resultados/confussion.pdf", bbox_inches="tight")
plt.savefig("Resultados/confussion.png", bbox_inches="tight")

# %%
FP = conf_mat.sum(axis=0) - np.diag(conf_mat) 
FN = conf_mat.sum(axis=1) - np.diag(conf_mat)
TP = np.diag(conf_mat)
TN = conf_mat.sum() - (FP + FN + TP)
FP = FP.astype(float)
FN = FN.astype(float)
TP = TP.astype(float)
TN = TN.astype(float)
# Specificity or true negative rate
TNR = TN/(TN+FP) 

print("Test Spec:", TNR)
print("Test Spec:", np.mean(TNR))
# Out:
# Test Spec: [0.97960775 0.97946201 0.96033969]
# Test Spec: 0.9731364828877549

# %%
#CALCULAR ROC AUC PARA CLASIFICACION MULTICLASE 
test_roc_auc_score1 = roc_auc_score(y_test_true, prediction, average="macro", multi_class="ovo")
test_roc_auc_score2 = roc_auc_score(y_test_true, prediction, average="macro", multi_class="ovr")
test_roc_auc_score3 = roc_auc_score(y_test_true, prediction, average="weighted", multi_class="ovo")
test_roc_auc_score4 = roc_auc_score(y_test_true, prediction, average="weighted", multi_class="ovr")  #Elegido

print("Test ROC AUC: {:.4f}".format(test_roc_auc_score1))
print("Test ROC AUC: {:.4f}".format(test_roc_auc_score2))
print("Test ROC AUC: {:.4f}".format(test_roc_auc_score3))
print("Test ROC AUC: {:.4f}".format(test_roc_auc_score4))
# Out:
# Test ROC AUC: 0.9927
# Test ROC AUC: 0.9928
# Test ROC AUC: 0.9927
# Test ROC AUC: 0.9930

# %%
data_generator = ImageDataGenerator()
test_flow_param = {
    "directory": test_dir,
    "target_size": IMAGE_SHAPE[:2],
    "batch_size" : 1,
    "shuffle": False 
}
test_flow = data_generator.flow_from_directory(**test_flow_param)
y_test_true = test_flow.classes
preds = model.predict_generator(test_flow, steps=len(test_flow))
predictions = np.argmax(preds, axis=1)

y_test = np.zeros((1057,3))
for i in range(y_test_true.shape[0]):
  y_test[i,y_test_true[i]] = 1
# Out:
# Found 1057 images belonging to 3 classes.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1905: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '

# %%
y_test_true = test_flow.classes
preds = model.predict_generator(test_flow, steps=len(test_flow))
predictions = np.argmax(preds, axis=1)
report = classification_report(y_test_true, predictions)  
print(report)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1905: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       319
#            1       0.93      0.92      0.92       244
#            2       0.96      0.96      0.96       494
#
#     accuracy                           0.95      1057
#    macro avg       0.95      0.95      0.95      1057
# weighted avg       0.95      0.95      0.95      1057

# %%
from sklearn.datasets import make_classification  
from sklearn.preprocessing import label_binarize  
from scipy import interp  
from itertools import cycle

n_classes = 3

from sklearn.metrics import roc_curve, auc

# Plot linewidth.
lw = 2

# Compute ROC curve and ROC area for each class
fpr = dict()  
tpr = dict()  
roc_auc = dict() 
for i in range(n_classes):  
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), preds.ravel())  
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Compute macro-average ROC curve and ROC area

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)  
for i in range(n_classes):  
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr  
tpr["macro"] = mean_tpr  
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure(figsize= (10,6))  
plt.plot(fpr["micro"], tpr["micro"],  
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],  
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['darkorange','green', 'magenta', 'red'])  
for i, color in zip(range(n_classes), colors):  
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)  
plt.xlim([0.0, 1.0])  
plt.ylim([0.0, 1.05])  
plt.xlabel('False Positive Rate')  
plt.ylabel('True Positive Rate')  
plt.title('Some extension of Receiver operating characteristic to multi-class')  
plt.legend(loc="lower right")  
plt.savefig("Resultados/ROC_curve.pdf", bbox_inches="tight")
plt.savefig("Resultados/ROC_curve.png", bbox_inches="tight")
plt.show()

# Zoom in view of the upper left corner.
plt.figure(figsize= (10,6))  
plt.xlim(0, 0.2)  
plt.ylim(0.8, 1)  
plt.plot(fpr["micro"], tpr["micro"],  
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],  
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['magenta', 'darkorange', 'green'])  
for i, color in zip(range(3), colors):  
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)  
plt.xlabel('False Positive Rate')  
plt.ylabel('True Positive Rate')  
plt.title('Some extension of Receiver operating characteristic to multi-class')  
plt.legend(loc="lower right")  
plt.savefig("Resultados/ROC_curve_zoom.pdf", bbox_inches="tight")
plt.savefig("Resultados/ROC_curve_zoom.png", bbox_inches="tight")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:33: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead

# %%
fprsave = {'fpr0': fpr[0],'fpr1': fpr[1],'fpr2': fpr[2],'fprmacro': fpr['macro'],'fprmicro': fpr['micro']}

tprsave = {'tpr0': tpr[0],'tpr1': tpr[1],'tpr2': tpr[2],'tprmacro': tpr['macro'],'tprmicro': tpr['micro']}

rocsave = {'roc0': roc_auc[0],'roc1': roc_auc[1],'roc2': roc_auc[2],'rocmacro': roc_auc['macro'],'rocmicro': roc_auc['micro']}

# %%
from scipy.io import savemat
import scipy.io as sio

sio.savemat('Resultados/fpr.mat',fprsave)
sio.savemat('Resultados/tpr.mat',tprsave)
sio.savemat('Resultados/roc.mat',rocsave)

# %%
from google.colab import files
# !zip -r resultados.zip Resultados
files.download('resultados.zip')
# Out:
#   adding: Resultados/ (stored 0%)
#   adding: Resultados/accuracy.pdf (deflated 33%)
#   adding: Resultados/loss.pdf (deflated 33%)
#   adding: Resultados/loss.png (deflated 5%)
#   adding: Resultados/accuracy.png (deflated 4%)
#   adding: Resultados/tpr.mat (deflated 43%)
#   adding: Resultados/confussion.png (deflated 10%)
#   adding: Resultados/confussion.pdf (deflated 42%)
#   adding: Resultados/ROC_curve.png (deflated 9%)
#   adding: Resultados/ROC_curve_zoom.png (deflated 7%)
#   adding: Resultados/ROC_curve_zoom.pdf (deflated 27%)
#   adding: Resultados/roc.mat (deflated 62%)
#   adding: Resultados/ROC_curve.pdf (deflated 26%)
#   adding: Resultados/fpr.mat (deflated 73%)
